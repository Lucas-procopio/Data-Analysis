# %% [markdown]
# <a href="https://www.kaggle.com/code/lucasdasilvaprocopio/word-cloud?scriptVersionId=98167884" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# Ignoring warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
base_dados = sns.load_dataset('iris')

base_dados.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
base_dados.shape #showing quantity lines and columns
# Out:
# (150, 5)

# %%
# mean
base_dados['petal_length'].mean()
# Out:
# 3.7580000000000005

# %%
# mode
base_dados['petal_length'].mode()
# Out:
# 0    1.4
# 1    1.5
# dtype: float64

# %%
# median
base_dados['petal_length'].median()
# Out:
# 4.35

# %%
'''
 mean: 3.75
 mode: 1.4 and 1.5
 median: 4.35
'''
# Out:
# '\n mean: 3.75\n mode: 1.4 and 1.5\n median: 4.35\n'

# %%
#Quarter

# %%
base_dados['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
sns.boxplot(base_dados['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
# Amplitude total

base_dados['sepal_length'].max() - base_dados['sepal_length'].min()
# Out:
# 3.6000000000000005

# %%
# Amplitude Interquatilica
# diferença do 3 ° Quartil para o 1° Quartil

base_dados['sepal_length'].describe()[6:7].values - base_dados['sepal_length'].describe()[4:5].values / 2
# Out:
# array([3.85])

# %%
# variância

base_dados['sepal_length'].var()
# Out:
# 0.6856935123042507

# %%
# Desvio padrão

base_dados['sepal_length'].std()
# Out:
# 0.828066127977863

# %%
# Medidas de Assimetria

# %%
# Calculando assimetria
base_dados['sepal_length'].skew()
# Out:
# 0.3149109566369728

# %%
sns.kdeplot(base_dados['sepal_length']);

# %%
# Medidas de curtose

base_dados['sepal_length'].kurtosis()
# Out:
# -0.5520640413156395

# %%
# Correlação de Pearson

base_dados.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap( base_dados.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot( data=base_dados, x='petal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
# correlação Spearman
# Quando os dados não forem lineares, devemos usar a correlação spearman

base_dados.corr('spearman')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.166778      0.881898     0.834289
# sepal_width      -0.166778     1.000000     -0.309635    -0.289032
# petal_length      0.881898    -0.309635      1.000000     0.937667
# petal_width       0.834289    -0.289032      0.937667     1.000000

# %%
sns.heatmap(base_dados.corr('spearman'), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot( data=base_dados, x='sepal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>
